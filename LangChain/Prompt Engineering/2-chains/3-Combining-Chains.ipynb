# %% [markdown]
# # Combining Chains

# %% [markdown]
# In this notebook you'll learn how to compose multiple LLM-related chains.

# %% [markdown]
# ---

# %% [markdown]
# ## Objectives

# %% [markdown]
# By the time you complete this notebook you will:
#
# - Learn how to compose chains of chains
# - Apply your ability to chain meaningful language tasks.

# %% [markdown]
# ---

# %%
# !pip install groq langchain-groq grandalf
# Out:
# Collecting groq
#   Downloading groq-0.31.1-py3-none-any.whl.metadata (16 kB)
# Collecting langchain-groq
#   Downloading langchain_groq-0.3.7-py3-none-any.whl.metadata (2.6 kB)
# Collecting grandalf
#   Downloading grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.12/dist-packages (from langchain-groq) (0.3.75)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from grandalf) (3.2.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (0.4.23)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (0.24.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (2.5.0)
# Downloading groq-0.31.1-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 8.2 MB/s eta 0:00:00
# Downloading langchain_groq-0.3.7-py3-none-any.whl (16 kB)
# Downloading grandalf-0.8-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: grandalf, groq, langchain-groq
# Successfully installed grandalf-0.8 groq-0.31.1 langchain-groq-0.3.7

# %% [markdown]
# ## Imports

# %%
import os
import getpass

os.environ["GROQ_API_KEY"] = getpass.getpass("GROQ API Key:\n")
# Out:
# GROQ API Key:
# ··········

# %%
from langchain_groq import ChatGroq

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableLambda

# %% [markdown]
# ---

# %% [markdown]
# ## Create a Model Instance

# %%
llm = ChatGroq(model_name="llama-3.3-70b-versatile", temperature=0)

# %% [markdown]
# ---

# %% [markdown]
# ## Combining Multiple LLM Chains

# %% [markdown]
# If you recall, runnables can be composed into chains, but also, chains are themselves runnables. Therefore, chains can be used to compose larger chains.
#
# It's easy to imagine tasks we would like to perform that would require multiple calls to an LLM for the desired end result. We'll begin our exploration of chaining chains with such a scenario, where we will compose multiple LLM chains, piping the output of one chain into the next.
#
# To do this we are going to work with the following list of `thesis_statements`. Note: any typos you see in the thesis statements are intentional.

# %%
thesis_statements = [
    "The fundametal concepts quantum physcis are difficult to graps, even for the mostly advanced students.",
    "Einstein's theroy of relativity revolutionised undrstanding of space and time, making it clear that they are interconnected.",
    "The first law of thermodynmics states that energy cannot be created or destoryed, excepting only transformed from one form to another.",
    "Electromagnetism is one of they four funadmental forces of nature, and it describes the interaction between charged particles.",
    "In the study of mechanic, Newton's laws of motion provide a comprehensive framework for understading the movement of objects under various forces."
]

# %% [markdown]
# Our goal is going to be to expand each of these thesis statements into a well-written paragraph, with the thesis statement itself being the first sentence. You may have noticed, however, that each of these thesis statements contains spelling and/or grammar errors that need correcting.
#
# Therefore, we are going to create a chain first to address the spelling and grammar issues, and then chain the corrected thesis statements into a second LLM chain responsible for generating the full paragraphs.

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise: Create a Spelling and Grammar Chain

# %% [markdown]
# To begin, create `grammar_chain` which returns its inputs after performing spelling and grammar corrections on them.
#
# We already have an LLM instance defined above (`llm`), but you will need to create both a prompt template and output parser to include in your chain.
#
# You may need to develop your prompt template iteratively. Make sure especially that the chain returns only the corrected text, and not any additional comments etc. from the model.
#
# Test your chain by sending it the batch of `thesis_statements` defined above.
#
# Check out the solution below if you get stuck.

# %% [markdown]
# ### Your Work Here

# %%
grammar_chain = 'TODO' # TODO: grammar_chain should return its inputs after performing spelling and grammar on them.

# %% [markdown]
# ### Solution

# %% [markdown]
# We begin by engineering a prompt for spelling and grammar correction. We take care to be specific in our prompt that the model should generate only the corrected text with no addional comment or preface.

# %%
spelling_and_grammar_template = ChatPromptTemplate.from_template("""Fix any spelling or grammatical issues in the following text. Return \
back the correct text and only the corrected text with no additional comment or preface. Text: {text}""")

# %% [markdown]
# Next we create an instance of a string output parser.

# %%
parser = StrOutputParser()

# %% [markdown]
# All that's left to do is compose the chain...

# %%
grammar_chain = spelling_and_grammar_template | llm | parser

# %% [markdown]
# ...and pass the thesis statements to it in batch.

# %%
corrected_texts = grammar_chain.batch(thesis_statements)

# %% [markdown]
# Looking at the corrected outputs, it appears that the model did an excellent job.

# %%
for corrected_text in corrected_texts:
    print(corrected_text)
# Out:
# The fundamental concepts of quantum physics are difficult to grasp, even for the most advanced students.
# Einstein's theory of relativity revolutionised understanding of space and time, making it clear that they are interconnected.
# The first law of thermodynamics states that energy cannot be created or destroyed, except that it can be transformed from one form to another.
# Electromagnetism is one of the four fundamental forces of nature, and it describes the interaction between charged particles.
# In the study of mechanics, Newton's laws of motion provide a comprehensive framework for understanding the movement of objects under various forces.

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise: Create a Paragraph Generator Chain

# %% [markdown]
# Create a second chain called `paragraph_generator_chain`. Given a sentence as input, it should use that sentence as the first sentence of a paragraph which it should generate.
#
# **Note:** this chain should not contain any grammar or spell checking functionality. The chain should be responsible only for the paragraph generation task.
#
# Test your chain by sending it the batch of `thesis_statements` defined above.
#
# Feel free to check out the *Solution* below if you get stuck.

# %% [markdown]
# ### Your Work Here

# %%
paragraph_generator_chain = 'TODO'

# %% [markdown]
# ### Solution

# %% [markdown]
# We begin the task by engineering a prompt.

# %%
paragraph_generator_template = ChatPromptTemplate.from_template("""Generate a 4 to 8 sentence paragraph that begins with the following \
thesis statement. Return back the paragraph and only the paragraph with no additional comment or preface. Thesis statement: {thesis}""")

# %% [markdown]
# Since we already have a model instance and parser, all we have to do is compose the chain...

# %%
paragraph_generator_chain = paragraph_generator_template | llm | parser

# %% [markdown]
# ...and send it the batch of thesis statements.

# %%
paragraphs = paragraph_generator_chain.batch(thesis_statements)

# %% [markdown]
# Looking at the generated paragraphs, it looks like the model did a great job.
#
# It's worth highlighing that even though we did not prompt the model to address spelling and grammar mistakes, it did fix some of the spelling mistakes anyway, however, it's clear that most of the grammar errors from the thesis statements we passed in are still present.

# %%
for paragraph in paragraphs:
    print(paragraph+'\n')
# Out:
# The fundamental concepts of quantum physics are difficult to grasp, even for the most advanced students. This is because quantum mechanics often defies classical intuition, introducing principles such as wave-particle duality and uncertainty that challenge traditional notions of space and time. The mathematical formulations that underpin quantum theory, including complex equations and probabilistic interpretations, can be particularly daunting for many learners. Furthermore, the abstract nature of quantum phenomena, which often occur at scales too small to be directly observed, makes it hard for students to develop a concrete understanding of these concepts. As a result, even students with a strong foundation in mathematics and physics may struggle to fully comprehend the intricacies of quantum physics. To overcome these challenges, educators and researchers are developing innovative teaching methods and tools, such as interactive simulations and visualizations, to help students better understand and engage with quantum concepts. Despite these efforts, mastering quantum physics remains a significant intellectual undertaking that requires dedication, persistence, and a deep passion for understanding the underlying principles of the universe. Ultimately, the rewards of grasping quantum physics are well worth the effort, as it holds the key to unlocking new technologies and advancing our understanding of the fundamental nature of reality.
#
# Einstein's theory of relativity revolutionised understanding of space and time, making it clear that they are interconnected. This fundamental concept challenged the long-held beliefs of absolute space and time, which were previously thought to be separate entities. The theory, which consists of special relativity and general relativity, introduced the concept of spacetime, a four-dimensional fabric that combines space and time. According to this theory, the laws of physics are the same everywhere in the universe, and the passage of time can be affected by gravity and motion. The implications of this theory were profound, leading to a deeper understanding of the nature of the universe, from the behaviour of black holes to the expansion of the cosmos. Furthermore, the theory of relativity has had a significant impact on the development of modern physics, influencing fields such as astrophysics, cosmology, and particle physics. As a result, our understanding of the universe has become more nuanced and complex, revealing the intricate relationships between space, time, and matter. The theory of relativity remains a cornerstone of modern physics, continuing to inspire new discoveries and advancements in our understanding of the universe.
#
# The first law of thermodynamics states that energy cannot be created or destroyed, excepting only transformed from one form to another. This fundamental principle has far-reaching implications for our understanding of the natural world, as it suggests that the total energy of a closed system remains constant over time. In other words, energy can change forms, such as from kinetic to potential or from thermal to electrical, but the overall amount of energy remains the same. For example, when a car engine burns gasoline, the chemical energy stored in the fuel is converted into mechanical energy, which propels the vehicle forward, and thermal energy, which is dissipated as heat. Similarly, when a hydroelectric dam generates electricity, the potential energy of the water is transformed into electrical energy, which is then transmitted to power homes and businesses. The first law of thermodynamics has been consistently supported by scientific observations and experiments, and it remains a cornerstone of modern physics and engineering. As a result, it has numerous practical applications, from the design of more efficient engines and power plants to the development of new technologies that harness and convert energy in innovative ways. By recognizing that energy is conserved and transformed, rather than created or destroyed, we can better understand and manage the complex interactions between energy, matter, and the environment.
#
# Electromagnetism is one of the four fundamental forces of nature, and it describes the interaction between charged particles. This force is responsible for the attraction and repulsion between particles with opposite or like charges, and it plays a crucial role in the structure and behavior of matter at all scales. From the smallest subatomic particles to the largest galaxies, electromagnetism is the force that holds atoms and molecules together, and it is also the force that allows for the transmission of energy in the form of light and other forms of electromagnetic radiation. The electromagnetic force is a universal force that acts over vast distances, and it is the force that governs the behavior of charged particles in all areas of the physical world. In addition to its role in the structure of matter, electromagnetism is also the force that underlies many of the technologies that are essential to modern life, including electricity, radio communication, and medical imaging. The study of electromagnetism has led to a deep understanding of the behavior of charged particles and the nature of light and other forms of electromagnetic radiation. As a result, electromagnetism is a fundamental concept in physics and engineering, and it continues to be an active area of research and development. The continued exploration of electromagnetism has the potential to lead to new technologies and a deeper understanding of the universe.
#
# In the study of mechanics, Newton's laws of motion provide a comprehensive framework for understanding the movement of objects under various forces. The first law, also known as the law of inertia, states that an object at rest will remain at rest, and an object in motion will continue to move with a constant velocity, unless acted upon by an external force. The second law relates the force applied to an object to its resulting acceleration, and is often expressed by the equation F = ma, where F is the net force, m is the mass of the object, and a is the acceleration. The third law, which states that every action has an equal and opposite reaction, helps to explain the interactions between objects and the resulting motions. By applying these laws, scientists and engineers can predict and analyze the motion of objects in a wide range of situations, from the trajectory of a thrown ball to the orbit of a planet. Additionally, Newton's laws have been widely used in the design and development of various machines and mechanisms, such as engines, gears, and brakes. Overall, the understanding and application of Newton's laws of motion have had a profound impact on the field of mechanics and continue to be a fundamental part of scientific and engineering education. The laws have also been used to make significant advancements in fields such as astronomy, materials science, and robotics.

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise: Create a Chain of Chains

# %% [markdown]
# Reusing the chains you've already created, create a `corrected_generator_chain` that uses the LLM first to perform spelling and grammar corrections on `thesis_statements` before then generating full paragraphs based the (corrected) thesis statements.
#
# You don't need to overthink this. Just remember, chains are runnables, and can be piped together just like any other runnable.
#
# Test your chain by sending it the batch of `thesis_statements` defined above.
#
# Feel free to check out the *Solution* below if you get stuck.

# %% [markdown]
# ### Your Work Here

# %% [markdown]
# ### Solution

# %% [markdown]
# All we have to do to create our larger chain is to pipe together the 2 chains we already created.

# %%
corrected_generator_chain = grammar_chain | paragraph_generator_chain

# %% [markdown]
# Just because it will be interesting, we can take a look at the computational graph for our new chain.

# %%
print(corrected_generator_chain.get_graph().draw_ascii())
# Out:
#      +-------------+
#      | PromptInput |
#      +-------------+
#             *
#             *
#             *
#   +--------------------+
#   | ChatPromptTemplate |
#   +--------------------+
#             *
#             *
#             *
#       +----------+
#       | ChatGroq |
#       +----------+
#             *
#             *
#             *
#    +-----------------+
#    | StrOutputParser |
#    +-----------------+
#             *
#             *
#             *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
#             *
#             *
#             *
#   +--------------------+
#   | ChatPromptTemplate |
#   +--------------------+
#             *
#             *
#             *
#       +----------+
#       | ChatGroq |
#       +----------+
#             *
#             *
#             *
#    +-----------------+
#    | StrOutputParser |
#    +-----------------+
#             *
#             *
#             *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+

# %% [markdown]
# We can batch send our thesis statements to this larger chain just as we did with the smaller chains.

# %%
paragraphs = corrected_generator_chain.batch(thesis_statements)

# %% [markdown]
# Looking at the final outputs we can see that the paragraphs were well-generated, but also, that all the spelling and grammar mistakes in the original thesis statements have been addressed.

# %%
for paragraph in paragraphs:
    print(paragraph+'\n')
# Out:
# The fundamental concepts of quantum physics are difficult to grasp, even for the most advanced students. This is due in part to the abstract nature of the subject, which often requires a significant departure from classical notions of space and time. Quantum mechanics introduces principles such as wave-particle duality, superposition, and entanglement, which can be challenging to visualize and understand. Furthermore, the mathematical framework that underlies quantum physics, including complex equations and probabilistic interpretations, can be daunting for many students. As a result, even those with a strong foundation in mathematics and physics may struggle to fully comprehend the intricacies of quantum physics. The counterintuitive nature of quantum phenomena, which often seem to defy everyday experience, can also contribute to the difficulty in grasping these concepts. Despite these challenges, researchers and students continue to explore and study quantum physics, driven by the promise of breakthroughs in fields such as materials science, computing, and medicine. Ultimately, a deep understanding of quantum physics requires a combination of mathematical sophistication, conceptual clarity, and persistence.
#
# Einstein's theory of relativity revolutionised understanding of space and time, making it clear that they are interconnected. This groundbreaking concept challenged traditional notions of absolute time and space, instead introducing the idea that they are relative and dependent on the observer's frame of reference. The theory, which consists of special relativity and general relativity, transformed the field of physics and had a profound impact on the development of modern astrophysics and cosmology. By introducing the famous equation E=mc², Einstein showed that mass and energy are also intertwined, further highlighting the complex relationships between space, time, and matter. The implications of relativity have been extensively tested and confirmed through numerous experiments and observations, including the bending of light around massive objects and the existence of black holes. As a result, our understanding of the universe has become more nuanced and sophisticated, revealing the intricate web of relationships that govern the behaviour of celestial objects and the fabric of spacetime itself. The influence of relativity extends beyond physics, with far-reaching implications for philosophy, mathematics, and our broader understanding of the human experience. Ultimately, Einstein's theory of relativity has left an indelible mark on human knowledge, forever changing the way we perceive and interact with the universe.
#
# The first law of thermodynamics states that energy cannot be created or destroyed, except that it can be transformed from one form to another. This fundamental principle has far-reaching implications in various fields, including physics, chemistry, and engineering. It suggests that the total energy of an isolated system remains constant over time, but the form of energy can change, such as from kinetic to potential or from thermal to electrical. For instance, a car engine converts chemical energy from fuel into mechanical energy, which is then used to propel the vehicle forward. Similarly, a solar panel transforms sunlight into electrical energy, which can be used to power homes and devices. The law also applies to biological systems, where energy from food is converted into mechanical energy for movement and other bodily functions. Overall, the first law of thermodynamics provides a framework for understanding the conservation and transformation of energy in different contexts. By recognizing that energy can only be transformed, not created or destroyed, scientists and engineers can design more efficient systems and technologies that minimize energy waste and maximize energy utilization.
#
# Electromagnetism is one of the four fundamental forces of nature, and it describes the interaction between charged particles. This force is responsible for the attraction and repulsion between positively and negatively charged particles, and it plays a crucial role in the structure and properties of matter. The electromagnetic force is carried by photons, which are massless particles that travel at the speed of light, and it is the force that holds electrons in orbit around the nucleus of an atom. In addition to its role in atomic structure, electromagnetism is also responsible for the forces that act between molecules, such as the van der Waals forces that hold molecules together in solids and liquids. The electromagnetic force is also the basis for many everyday phenomena, including the behavior of magnets and the propagation of light and other forms of electromagnetic radiation. Furthermore, electromagnetism has numerous practical applications, including the generation and transmission of electricity, the operation of electronic devices, and the functioning of communication systems. Overall, the electromagnetic force is a fundamental aspect of the physical world, and its effects are ubiquitous and essential to the functioning of the universe. The study of electromagnetism has led to a deep understanding of the behavior of charged particles and the structure of matter, and it continues to be an active area of research and discovery.
#
# In the study of mechanics, Newton's laws of motion provide a comprehensive framework for understanding the movement of objects under various forces. The first law, also known as the law of inertia, states that an object at rest will remain at rest, and an object in motion will continue to move with a constant velocity, unless acted upon by an external force. The second law relates the force applied to an object to its resulting acceleration, and is often expressed by the equation F = ma, where F is the net force, m is the mass of the object, and a is the acceleration. The third law, which deals with the interaction between two objects, states that every action has an equal and opposite reaction, providing a fundamental understanding of how forces are transmitted between objects. By applying these laws, scientists and engineers can predict the motion of objects, from the trajectory of a projectile to the orbit of a planet. Additionally, Newton's laws have numerous practical applications in fields such as engineering, physics, and astronomy, allowing for the design and optimization of complex systems. Overall, Newton's laws of motion remain a cornerstone of classical mechanics, providing a powerful tool for understanding and describing the natural world. The widespread applicability and simplicity of these laws have made them a fundamental component of scientific education and research.

# %% [markdown]
# ---

# %% [markdown]
# # Task
# Create a Langchain LCEL pipeline that includes a custom data cleaning function and a sentiment analysis chain.

# %% [markdown]
# ## Define a custom data cleaning function
#
# ### Subtask:
# Create a Python function to clean the input text data.

# %% [markdown]
# **Reasoning**:
# The subtask requires creating a Python function to clean text data. This involves defining the function, converting the input to lowercase, and removing whitespace.

# %%
def clean_text(text: str) -> str:
    """
    Cleans the input text by converting to lowercase and removing leading/trailing whitespace.

    Args:
        text: The input string to clean.

    Returns:
        The cleaned string.
    """
    text = text.lower()
    text = text.strip()
    return text

# %% [markdown]
# ## Create a sentiment analysis chain
#
# ### Subtask:
# Build a Langchain chain using an LLM to perform sentiment analysis.

# %% [markdown]
# **Reasoning**:
# Create the sentiment analysis prompt template, the sentiment analysis chain by piping the prompt, llm, and parser, and store it in `sentiment_chain`.

# %%
sentiment_prompt = ChatPromptTemplate.from_template("""Analyze the sentiment of the following text and return a single word: "positive", "negative", or "neutral". Text: {text}""")
sentiment_chain = sentiment_prompt | llm | parser
