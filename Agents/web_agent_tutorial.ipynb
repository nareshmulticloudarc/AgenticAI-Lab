# %% [markdown]
# # Build a Web Research Agent
#
# In the first exercise, you learned the basics of the
# Tavily API. Now, let's take it a step further: we'll
# combine that knowledge with LLMs to unlock
# real value. In this tutorial, you'll learn how to build a web research agent that can search, extract, crawl, and reason over live web data.
#
# You already explored the various parameter
# configurations available for each Tavily API endpoint.
# With the official [Tavily-LangChain integration](https://www.tavily.com/integrations/langchain) integration, our agent can
# automatically set these parameters—like the
# `time_range` for search or specific crawl
# `instructions`—based on the context and requirements of
# each task. This dynamic, LLM-powered configuration is
# powerful in agentic systems.
#
# By the end of this lesson, you'll know how to:
# - Seamlessly connect foundation models to the web for up-to-date research
# - Build a react-style web agent
# - Dynamically configure search, extract, and crawl parameters the Tavily-LangChain integration.
#
#
#
# ---

# %% [markdown]
# ## Getting Started
#
# Follow these steps to set up:
#
# 1. **Sign up** for Tavily at https://www.tavily.com/

# %% [markdown]
# Install dependencies in the cell below.

# %%
# %pip install -U tavily-python langchain-openai langchain langchain-tavily langgraph --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.7/216.7 kB 8.3 MB/s eta 0:00:00

# %% [markdown]
# ### Setting Up Your Tavily API Client
#
# The code below will instantiate the Tavily client with your API key.

# %%
import os
import getpass
from tavily import TavilyClient

# Prompt the user to securely input the API key if not already set in the environment

os.environ["TAVILY_API_KEY"] = getpass.getpass("TAVILY_API_KEY:\n")
os.environ["OPENAI_API_KEY"] = getpass.getpass("OPENAI API Key:\n")

# Initialize the Tavily API client using the loaded or provided API key
tavily_client = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))
# Out:
# TAVILY_API_KEY:
# ··········
# OPENAI API Key:
# ··········

# %% [markdown]
# Let's define the following modular tools with the Tavily-LangChain integration:
# 1. **Search** the web for relevant information
#
# 2. **Extract** content from specific web pages
#
# 3. **Crawl** entire websites

# %%
# Define the set of web tools our agent will use to interact with the Tavily API.
from langchain_tavily import TavilySearch
from langchain_tavily import TavilyExtract
from langchain_tavily import TavilyCrawl

# Define the LangChain search tool
search = TavilySearch(max_results=10, topic="general")

# Define the LangChain extract tool
extract = TavilyExtract(extract_depth="advanced")

# Define the LangChain crawl tool
crawl = TavilyCrawl()

# %% [markdown]
# Now let's set up several OpenAI foundation models to power our agent, such as o3-mini and the gpt-4.1 model. If you prefer a different LLM provider, you can easily plug in any LangChain Chat Model.

# %%
# Instantiate the OpenAI foundation models
from langchain_openai import ChatOpenAI

# o3-mini-2025-01-31
o3_mini = ChatOpenAI(model="o3-mini-2025-01-31", api_key=os.getenv("OPENAI_API_KEY"))

# gpt-4.1
gpt_4_1 = ChatOpenAI(model="gpt-4.1", api_key=os.getenv("OPENAI_API_KEY"))

# %% [markdown]
# ## Web Agent
#
# Next, we'll build a Web Agent powered by Tavily, which consists of three main components: the language model, a set of web tools, and a system prompt. The language model (such as o3-mini or gpt-4.1) serves as the agent's "brain," while the web tools (Search, Extract, and Crawl) allow the agent to interact with and gather information from the internet. The system prompt guides the agent's behavior, explaining how and when to use each tool to accomplish its research goals.
#
# This agent leverages a pre-built LangGraph reAct implementation. The reAct framework enables the agent to reason about which actions to take, use the web tools in sequence, and iterate as needed until it completes its research task. The system prompt is especially important—it instructs the agent on best practices for using the tools together, ensuring that the agent's responses are thorough, accurate, and well-sourced.
#
# You are encouraged to experiment with the system prompt or try different language models (like swapping between gpt-4.1 and o3-mini) to change the agent's style, personality, or optimize its performance for specific use cases.

# %%
import datetime
from langgraph.prebuilt import create_react_agent
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

today = datetime.datetime.today().strftime("%A, %B %d, %Y")

# Create the web agent
web_agent = create_react_agent(
    model=gpt_4_1,
    tools=[search, extract, crawl],
    prompt=ChatPromptTemplate.from_messages(
        [
            (
                "system",
                f"""
        You are a research agent equipped with advanced web tools: Tavily Web Search, Web Crawl, and Web Extract. Your mission is to conduct comprehensive, accurate, and up-to-date research, grounding your findings in credible web sources.

        **Today's Date:** {today}

        **Available Tools:**

        1. **Tavily Web Search**

        * **Purpose:** Retrieve relevant web pages based on a query.
        * **Usage:** Provide a search query to receive semantically ranked results, each containing the title, URL, and a content snippet.
        * **Best Practices:**

            * Use specific queries to narrow down results.
            * Optimize searches using parameters such as `search_depth`, `time_range`, `include_domains`, and `include_raw_content`.
            * Break down complex queries into specific, focused sub-queries.

        2. **Tavily Web Crawl**

        * **Purpose:** Explore a website's structure and gather content from linked pages for deep research and information discovery from a single source.
        * **Usage:** Input a base URL to crawl, specifying parameters such as `max_depth`, `max_breadth`, and `extract_depth`.
        * **Best Practices:**

            * Begin with shallow crawls and progressively increase depth.
            * Utilize `select_paths` or `exclude_paths` to focus the crawl.
            * Set `extract_depth` to "advanced" for comprehensive extraction.

        3. **Tavily Web Extract**

        * **Purpose:** Extract the full content from specific web pages.
        * **Usage:** Provide URLs to retrieve detailed content.
        * **Best Practices:**

            * Set `extract_depth` to "advanced" for detailed content, including tables and embedded media.
            * Enable `include_images` if image data is necessary.

        **Guidelines for Conducting Research:**

        * **Citations:** Always support findings with source URLs, clearly provided as in-text citations.
        * **Accuracy:** Rely solely on data obtained via provided tools—never fabricate information.
        * **Methodology:** Follow a structured approach:

        * **Thought:** Consider necessary information and next steps.
        * **Action:** Select and execute appropriate tools.
        * **Observation:** Analyze obtained results.
        * Repeat Thought/Action/Observation cycles as needed.
        * **Final Answer:** Synthesize and present findings with citations in markdown format.

        **Example Workflows:**

        **Workflow 1: Search Only**

        **Question:** What are recent news headlines about artificial intelligence?

        * **Thought:** I need quick, recent articles about AI.
        * **Action:** Use Tavily Web Search with the query "recent artificial intelligence news" and set `time_range` to "week".
        * **Observation:** Retrieved 10 relevant articles from reputable news sources.
        * **Final Answer:** Summarize key headlines with citations.

        **Workflow 2: Search and Extract**

        **Question:** Provide detailed insights into recent advancements in quantum computing.

        * **Thought:** I should find recent detailed articles first.
        * **Action:** Use Tavily Web Search with the query "recent advancements in quantum computing" and set `time_range` to "month".
        * **Observation:** Retrieved 10 relevant results.
        * **Thought:** I should extract content from the most comprehensive article.
        * **Action:** Use Tavily Web Extract on the most relevant URL from search results.
        * **Observation:** Extracted detailed information about quantum computing advancements.
        * **Final Answer:** Provide detailed insights summarized from extracted content with citations.

        **Workflow 3: Search and Crawl**

        **Question:** What are the latest advancements in renewable energy technologies?

        * **Thought:** I need recent articles about advancements in renewable energy.
        * **Action:** Use Tavily Web Search with the query "latest advancements in renewable energy technologies" and set `time_range` to "month".
        * **Observation:** Retrieved 10 articles discussing recent developments in solar panels, wind turbines, and energy storage.
        * **Thought:** To gain deeper insights, I'll crawl a relevant industry-leading renewable energy site.
        * **Action:** Use Tavily Web Crawl on the URL of a leading renewable energy industry website, setting `max_depth` to 2.
        * **Observation:** Gathered extensive content from multiple articles linked on the site, highlighting new technologies and innovations.
        * **Final Answer:** Provide a synthesized summary of findings with citations.

        ---

        You will now receive a research question from the user:

        """,
            ),
            MessagesPlaceholder(variable_name="messages"),
        ]
    ),
    name="web_agent",
)

# %% [markdown]
#         **Today's Date:** {today}
#
#         **Available Tools:**
#
#         1. **Tavily Web Search**
#
#         * **Purpose:** Retrieve relevant web pages based on a query.
#         * **Usage:** Provide a search query to receive semantically ranked results, each containing the title, URL, and a content snippet.
#         * **Best Practices:**
#
#             * Use specific queries to narrow down results.
#             * Optimize searches using parameters such as `search_depth`, `time_range`, `include_domains`, and `include_raw_content`.
#             * Break down complex queries into specific, focused sub-queries.

# %% [markdown]
# ### Test Your Tavily Web Agent
#
# Now we'll run the agent and see how it uses the different web tools.

# %%
from langchain.schema import HumanMessage

# Test the web agent
inputs = {
    "messages": [
        HumanMessage(
            content="find all the iphone models currently available on apple.com and their prices"
        )
    ]
}

# Stream the web agent's response
for s in web_agent.stream(inputs, stream_mode="values"):
    message = s["messages"][-1]
    if isinstance(message, tuple):
        print(message)
    else:
        message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# find all the iphone models currently available on apple.com and their prices
# ================================== Ai Message ==================================
# Name: web_agent
# Tool Calls:
#   tavily_search (call_qRNWZ6VrIl6hRWAeQyjDD1uk)
#  Call ID: call_qRNWZ6VrIl6hRWAeQyjDD1uk
#   Args:
#     query: current iPhone models and prices site:apple.com
#     search_depth: advanced
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "current iPhone models and prices", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://news.macgasm.net/iphone-news/iphone-17-expectations/", "title": "What to Expect From Apple's iPhone 17 Lineup This September", "content": "As for pricing, don’t hold your breath for anything “affordable.” The iPhone 17 will probably stay around the $799 mark, while the new iPhone 17 Air is expected to cost somewhere between $899 and $999. Apple wants it to replace the Plus in price, not just in name. The Pro models could see a bump. Reports suggest that Apple may raise prices slightly this year, especially on the Pro Max, which now needs to cover its triple 48MP sensors, upgraded chassis, and whatever else Apple throws in there. [...] Some estimates place the starting price for the iPhone 17 Pro Max at $1,299. [...] ## What iPhone Models Are on the Table This Year?\n\nIf Apple follows its usual playbook, we’ll see four models in the iPhone 17 lineup: the regular iPhone 17, a new mid-tier model, the iPhone 17 Pro, and the iPhone 17 Pro Max. But there’s a small shake-up this time. The Plus model (Apple’s habitually overlooked oversized option) looks ready for retirement. In its place, Apple plans to introduce the new iPhone 17 Air.", "score": 0.70580584, "raw_content": null}, {"url": "https://www.ign.com/articles/all-iphone-release-dates-in-order", "title": "Every iPhone Generation: A Full History of Release Dates - IGN", "content": "The September Apple event has just revealed the latest iPhone 17 phones, all of which will be available starting on September 19. The biggest updates this year came to the iPhone Pro models, which now include a vapor chamber welded into the chassis to help dissipate heat. All three cameras on the Pro are \"Fusion cameras\" and the main lens includes a 48MP telephoto. The iPhone 17 is priced at $799 and the Pro starts at $1,099. There is no iPhone Plus this generation as it has been replaced with [...] ### Apple iPhone 16 (Unlocked)\n\n### iPhone 16e - February 28, 2025\n\nApple has revealed the new iPhone 16e, announcing that would replace the outdated iPhone SE line from 2022. As the cheapest new iPhone, it comes with a price tag of $599, which is only $200 less than the standard iPhone 16. It's the first phone to feature Apple's C1 cellular modem, which we haven't had the chance to test just yet.\n\nApple iPhone 16e (Unlocked)\n\n### Apple iPhone 16e (Unlocked)\n\n### iPhone 17 - September 19, 2025 [...] The iPhone XR acted as 2018's budget friendly iPhone model. This device utilized a LCD display instead of the OLED display found on the iPhone X and iPhone XS. It also included only one camera on the back, similar to iPhone 8. Overall, the iPhone XR offered a similar experience to the premium iPhone X and iPhone XS at an affordable price point.\n\n### iPhone 11 - September 20, 2019", "score": 0.6929958, "raw_content": null}, {"url": "https://www.engadget.com/mobile/smartphones/best-iphone-160012979.html", "title": "The best iPhones for 2025: Which model should you buy? - Engadget", "content": "Apple is still selling the last-gen iPhone 16 and iPhone 16 Plus for $699 and $799, respectively, but the improvements made with the iPhone 17 have forced both devices into something of a no man’s land. The 16 Plus and its 6.7-inch display might be worth it if you want a large-screen iPhone for a much lower price than the iPhone 17 Pro Max, but you’ll miss out on the base model’s 120Hz always-on display and upgraded dual-camera setup. If you just want a usable iPhone for as little as possible, [...] Here’s the reality: There’s no such thing as a true budget iPhone in 2025. The $429 iPhone SE was the closest thing Apple had to a value-oriented model coming into the year, but it was officially discontinued in February, and its severely outdated design made it difficult to recommend long before that. The Phone 16e is the SE’s ostensible replacement, but it costs $599, well above  ...
# ================================== Ai Message ==================================
# Name: web_agent
# Tool Calls:
#   tavily_extract (call_j5cSBHa2K4UFdKV7sWycZETA)
#  Call ID: call_j5cSBHa2K4UFdKV7sWycZETA
#   Args:
#     urls: ['https://www.apple.com/iphone/']
#     extract_depth: advanced
# ================================= Tool Message =================================
# Name: tavily_extract
#
# {"results": [{"url": "https://www.apple.com/iphone/", "raw_content": "iPhone - Apple\n\n===============\n\nChoose another country or region to see content specific to your location.\n\nIsrael\n\n*   Israel\n*   Other country or region\n\n[Continue](https://www.apple.com/il/iphone/)\n\n*   [Apple](https://www.apple.com/)\n*   \n    *   [Store](https://www.apple.com/us/shop/goto/store)\n\nShop\n----\n\n    *   [Shop the Latest](https://www.apple.com/us/shop/goto/store)\n    *   [Mac](https://www.apple.com/us/shop/goto/buy_mac)\n    *   [iPad](https://www.apple.com/us/shop/goto/buy_ipad)\n    *   [iPhone](https://www.apple.com/us/shop/goto/buy_iphone)\n    *   [Apple Watch](https://www.apple.com/us/shop/goto/buy_watch)\n    *   [Apple Vision Pro](https://www.apple.com/us/shop/goto/buy_vision)\n    *   [AirPods](https://www.apple.com/us/shop/goto/airpods/accessories)\n    *   [Accessories](https://www.apple.com/us/shop/goto/buy_accessories)\n\nQuick Links\n-----------\n\n    *   [Find a Store](https://www.apple.com/retail/)\n    *   [Order Status](https://www.apple.com/us/shop/goto/order/list)\n    *   [Apple Trade In](https://www.apple.com/us/shop/goto/trade_in)\n    *   [Financing](https://www.apple.com/us/shop/goto/payment_plan)\n    *   [Personal Setup](https://www.apple.com/us/shop/goto/personal_setup)\n    *   [College Student Offer](https://www.apple.com/us/shop/goto/edu_store)\n\nShop Special Stores\n-------------------\n\n    *   [Certified Refurbished](https://www.apple.com/us/shop/goto/special_deals)\n    *   [Education](https://www.apple.com/us/shop/goto/educationrouting)\n    *   [Business](https://www.apple.com/retail/business/)\n    *   [Veterans and Military](https://www.apple.com/us/shop/goto/eppstore/veteransandmilitary)\n    *   [Government](https://www.apple.com/r/store/government/)\n\n    *   [Mac](https://www.apple.com/mac/)\n\nExplore Mac\n-----------\n\n    *   [Explore All Mac](https://www.apple.com/mac/)\n    *   [MacBook Air](https://www.apple.com/macbook-air/)\n    *   [MacBook Pro](https://www.apple.com/macbook-pro/)\n    *   [iMac](https://www.apple.com/imac/)\n    *   [Mac mini](https://www.apple.com/mac-mini/)\n    *   [Mac Studio](https://www.apple.com/mac-studio/)\n    *   [Mac Pro](https://www.apple.com/mac-pro/)\n    *   [Displays](https://www.apple.com/displays/)\n    *   [Compare Mac](https://www.apple.com/mac/compare/)\n    *   [Switch from PC to Mac](https://www.apple.com/mac/mac-does-that/)\n\nShop Mac\n--------\n\n    *   [Shop Mac](https://www.apple.com/us/shop/goto/buy_mac)\n    *   [Help Me Choose](https://www.apple.com/mac/best-mac/)\n    *   [Mac Accessories](https://www.apple.com/us/shop/goto/mac/accessories)\n    *   [Apple Trade In](https://www.apple.com/us/shop/goto/trade_in#mac)\n    *   [Financing](https://www.apple.com/us/shop/goto/payment_plan)\n    *   [College Student Offer](https://www.apple.com/us/shop/goto/edu_store)\n\nMore from Mac\n-------------\n\n    *   [Mac Support](https://support.apple.com/mac?cid=gn-ols-mac-psp-prodfly)\n    *   [AppleCare](https://www.apple.com/applecare/?filter=mac)\n    *   [macOS Tahoe](https://www.apple.com/os/macos/)\n    *   [Apple Intelligence](https://www.apple.com/apple-intelligence/)\n    *   [Apps by Apple](https://www.apple.com/apps/)\n    *   [Continuity](https://www.apple.com/macos/continuity/)\n    *   [iCloud+](https://www.apple.com/icloud/)\n    *   [Mac for Business](https://www.apple.com/business/mac/)\n    *   [Education](https://www.apple.com/education/)\n    *   [Accessibility](https://www.apple.com/accessibility/)\n\n    *   [iPad](https://www.apple.com/ipad/)\n\nExplore iPad\n------------\n\n    *   [Explore All iPad](https://www.apple.com/ipad/)\n    *   [iPad Pro](https://www.apple.com/ipad-pro/)\n    *   [iPad Air](https://www.apple.com/ipad-air/)\n    *   [iPad](https://www.apple.com/ipad-11/)\n    *   [iPad mini](https://www.apple.com/ipad-mini/)\n    *   [Apple Pencil](https://www.apple.com/apple-pencil/)\n    *    ...
# ================================== Ai Message ==================================
# Name: web_agent
# Tool Calls:
#   tavily_extract (call_dD6dVO8Ll5XKYDtldo0UTBIc)
#  Call ID: call_dD6dVO8Ll5XKYDtldo0UTBIc
#   Args:
#     urls: ['https://www.apple.com/us/shop/goto/buy_iphone']
#     extract_depth: advanced
# ================================= Tool Message =================================
# Name: tavily_extract
#
# {"results": [{"url": "https://www.apple.com/us/shop/goto/buy_iphone", "raw_content": "Buy iPhone - Apple\n\n===============\n\n*   [Apple](https://www.apple.com/)\n*   \n    *   [Store](https://www.apple.com/store)\n\nShop\n----\n\n    *   [Shop the Latest](https://www.apple.com/store)\n    *   [Mac](https://www.apple.com/shop/buy-mac)\n    *   [iPad](https://www.apple.com/shop/buy-ipad)\n    *   [iPhone](https://www.apple.com/shop/buy-iphone)\n    *   [Apple Watch](https://www.apple.com/shop/buy-watch)\n    *   [Apple Vision Pro](https://www.apple.com/us/shop/goto/buy_vision)\n    *   [Accessories](https://www.apple.com/shop/accessories/all)\n\nQuick Links\n-----------\n\n    *   [Find a Store](https://www.apple.com/retail/)\n    *   [Order Status](https://secure.store.apple.com/shop/order/list)\n    *   [Apple Trade In](https://www.apple.com/shop/trade-in)\n    *   [Financing](https://www.apple.com/shop/browse/finance/instant_credit)\n    *   [Personal Setup](https://www.apple.com/us/shop/goto/personal_setup)\n    *   [College Student Offer](https://www.apple.com/store)\n\nShop Special Stores\n-------------------\n\n    *   [Certified Refurbished](https://www.apple.com/shop/refurbished)\n    *   [Education](https://www.apple.com/shop/browse/home/education_routing)\n    *   [Business](https://www.apple.com/retail/business/)\n    *   [Veterans and Military](https://www.apple.com/shop/browse/home/veterans_military)\n    *   [Government](https://www.apple.com/r/store/government/)\n\n    *   [Mac](https://www.apple.com/mac/)\n\nExplore Mac\n-----------\n\n    *   [Explore All Mac](https://www.apple.com/mac/)\n    *   [MacBook Air](https://www.apple.com/macbook-air/)\n    *   [MacBook Pro](https://www.apple.com/macbook-pro/)\n    *   [iMac](https://www.apple.com/imac/)\n    *   [Mac mini](https://www.apple.com/mac-mini/)\n    *   [Mac Studio](https://www.apple.com/mac-studio/)\n    *   [Mac Pro](https://www.apple.com/mac-pro/)\n    *   [Displays](https://www.apple.com/displays/)\n    *   [Compare Mac](https://www.apple.com/mac/compare/)\n    *   [Switch from PC to Mac](https://www.apple.com/mac/mac-does-that/)\n\nShop Mac\n--------\n\n    *   [Shop Mac](https://www.apple.com/shop/buy-mac)\n    *   [Help Me Choose](https://www.apple.com/mac/best-mac/)\n    *   [Mac Accessories](https://www.apple.com/shop/mac/accessories)\n    *   [Apple Trade In](https://www.apple.com/shop/trade-in)\n    *   [Financing](https://www.apple.com/shop/browse/finance/instant_credit)\n    *   [College Student Offer](https://www.apple.com/store)\n\nMore from Mac\n-------------\n\n    *   [Mac Support](https://support.apple.com/mac?cid=gn-ols-mac-psp-prodfly)\n    *   [AppleCare+ for Mac](https://www.apple.com/support/products/mac/)\n    *   [macOS Tahoe 26 Preview](https://www.apple.com/os/macos/)\n    *   [Apple Intelligence](https://www.apple.com/apple-intelligence/)\n    *   [Apps by Apple](https://www.apple.com/apps/)\n    *   [Continuity](https://www.apple.com/macos/continuity/)\n    *   [iCloud+](https://www.apple.com/icloud/)\n    *   [Mac for Business](https://www.apple.com/business/mac/)\n    *   [Education](https://www.apple.com/education/)\n\n    *   [iPad](https://www.apple.com/ipad/)\n\nExplore iPad\n------------\n\n    *   [Explore All iPad](https://www.apple.com/ipad/)\n    *   [iPad Pro](https://www.apple.com/ipad-pro/)\n    *   [iPad Air](https://www.apple.com/ipad-air/)\n    *   [iPad](https://www.apple.com/ipad-11/)\n    *   [iPad mini](https://www.apple.com/ipad-mini/)\n    *   [Apple Pencil](https://www.apple.com/apple-pencil/)\n    *   [Keyboards](https://www.apple.com/ipad-keyboards/)\n    *   [Compare iPad](https://www.apple.com/ipad/compare/)\n    *   [Why iPad](https://www.apple.com/ipad/why-ipad/)\n\nShop iPad\n---------\n\n    *   [Shop iPad](https://www.apple.com/shop/buy-ipad)\n    *   [iPad Accessories](https://www.apple.com/shop/ipad/accessories)\n    *   [Apple Trade In](https://www.apple.com/shop/trade-in)\n    *   [Financ ...
# ================================== Ai Message ==================================
# Name: web_agent
#
# Based on the most current official information from Apple’s website, here are all the iPhone models currently available for purchase directly from Apple in the United States, along with their starting prices:
#
# ### Currently Available iPhone Models and Their Prices (as of September 2025):
#
# 1. **iPhone 17 Pro**
#    - Starting at $1,099
# 2. **iPhone 17**
#    - Starting at $799
# 3. **iPhone Air** (the new mid-tier model, thinner than the Plus, new for 2025)
#    - Starting at $999
# 4. **iPhone 16**
#    - Starting at $699
# 5. **iPhone 16e** (the “entry” or value model, successor to the SE line)
#    - Starting at $599
# 6. **iPhone 15** (previous generation, still sold by Apple)
#    - Starting at $699
#
# > - All these base prices are for the entry-level storage options, and actual prices may vary depending on trade-in, financing options and activation requirements for connectivity discounts.
#
# **Source:**
# - [Apple Official iPhone Shop Page](https://www.apple.com/us/shop/goto/buy_iphone)
# - [Apple iPhone Product Page](https://www.apple.com/iphone/)
#
# You can see more details, options, and offers directly on Apple's official store: [apple.com/us/shop/goto/buy_iphone](https://www.apple.com/us/shop/goto/buy_iphone).
#
# ---
#
# **Summary Table:**
#
# | Model          | Starting Price |
# |----------------|:-------------:|
# | iPhone 17 Pro  |   $1,099      |
# | iPhone 17      |   $799        |
# | iPhone Air     |   $999        |
# | iPhone 16      |   $699        |
# | iPhone 16e     |   $599        |
# | iPhone 15      |   $699        |
#
# For complete pricing, storage configurations, and current deals, always refer to the [official Apple store page](https://www.apple.com/us/shop/goto/buy_iphone).

# %% [markdown]
# Examine the agent's intermediate steps printed above, including how it chooses and configures different tool parameters. Then, display the agent's final answer in markdown format.

# %%
from IPython.display import Markdown

Markdown(message.content)
# Out:
# Based on the most current official information from Apple’s website, here are all the iPhone models currently available for purchase directly from Apple in the United States, along with their starting prices:
#
# ### Currently Available iPhone Models and Their Prices (as of September 2025):
#
# 1. **iPhone 17 Pro**
#    - Starting at $1,099
# 2. **iPhone 17**
#    - Starting at $799
# 3. **iPhone Air** (the new mid-tier model, thinner than the Plus, new for 2025)
#    - Starting at $999
# 4. **iPhone 16**
#    - Starting at $699
# 5. **iPhone 16e** (the “entry” or value model, successor to the SE line)
#    - Starting at $599
# 6. **iPhone 15** (previous generation, still sold by Apple)
#    - Starting at $699
#
# > - All these base prices are for the entry-level storage options, and actual prices may vary depending on trade-in, financing options and activation requirements for connectivity discounts.
#
# **Source:**
# - [Apple Official iPhone Shop Page](https://www.apple.com/us/shop/goto/buy_iphone)
# - [Apple iPhone Product Page](https://www.apple.com/iphone/)
#
# You can see more details, options, and offers directly on Apple's official store: [apple.com/us/shop/goto/buy_iphone](https://www.apple.com/us/shop/goto/buy_iphone).
#
# ---
#
# **Summary Table:**
#
# | Model          | Starting Price |
# |----------------|:-------------:|
# | iPhone 17 Pro  |   $1,099      |
# | iPhone 17      |   $799        |
# | iPhone Air     |   $999        |
# | iPhone 16      |   $699        |
# | iPhone 16e     |   $599        |
# | iPhone 15      |   $699        |
#
# For complete pricing, storage configurations, and current deals, always refer to the [official Apple store page](https://www.apple.com/us/shop/goto/buy_iphone).

# %% [markdown]
# Let's try a different example.

# %%
# Test the web agent
inputs = {
    "messages": [
        HumanMessage(
            content="return 5 job postings for a software engineer in the bay area on linkedin"
        )
    ]
}

# Stream the web agent's response
for s in web_agent.stream(inputs, stream_mode="values"):
    message = s["messages"][-1]
    if isinstance(message, tuple):
        print(message)
    else:
        message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# return 5 job postings for a software engineer in the bay area on linkedin
# ================================== Ai Message ==================================
# Name: web_agent
# Tool Calls:
#   tavily_search (call_MUo8mp9sRD8gq6ia9IK1URHJ)
#  Call ID: call_MUo8mp9sRD8gq6ia9IK1URHJ
#   Args:
#     query: software engineer jobs Bay Area site:linkedin.com/jobs
#     search_depth: advanced
#     time_range: week
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "software engineer jobs Bay Area site:linkedin.com/jobs", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.linkedin.com/jobs/view/software-engineer-developer-infra-at-tecton-4269808648", "title": "Software Engineer, Developer Infra - Tecton", "content": "Get notified about new Software Engineer jobs in San Francisco Bay Area. ... Java Specialist jobs · Dotnet Developer jobs · Senior PHP Developer jobs · Computer", "score": 0.71425, "raw_content": null}, {"url": "https://www.linkedin.com/jobs/view/software-engineer-i-front-end-full-stack-entry-level-at-jobright-ai-4269775633", "title": "Software Engineer I (Front End/Full Stack), Entry Level", "content": "Get notified about new Software Engineer jobs in San Francisco Bay Area. Sign in to create job alert.", "score": 0.7067782, "raw_content": null}, {"url": "https://www.linkedin.com/jobs/view/software-engineer-new-grad-internship-at-jobright-ai-4268514143", "title": "Jobright.ai hiring Software Engineer - New Grad (Internship)", "content": "Get notified about new Software Engineer jobs in San Francisco Bay Area. ... Software Engineer (Early Career). Phonely (YC S24). San Francisco, CA $60,000", "score": 0.6977124, "raw_content": null}, {"url": "https://www.linkedin.com/jobs/view/software-engineer-at-understanding-recruitment-4267476299", "title": "Software Engineer - Understanding Recruitment", "content": "Get notified about new Software Engineer jobs in San Francisco Bay Area. Sign in to create job alert. Apply. Similar jobs. Software Engineer, Backend. Software", "score": 0.6964752, "raw_content": null}, {"url": "https://www.linkedin.com/jobs/view/software-engineer-product-entry-level-at-jobright-ai-4270230839", "title": "Jobright.ai hiring Software Engineer, Product (Entry Level) ...", "content": "Software Engineer, Product (Entry Level). Jobright.ai San Francisco Bay Area. Just now Be among the first 25 applicants.", "score": 0.65676886, "raw_content": null}, {"url": "https://www.linkedin.com/jobs/view/software-engineer-entry-level-at-jobright-ai-4270764352", "title": "Software Engineer (Entry Level) - Jobright.ai", "content": "Get notified about new Software Engineer jobs in San Francisco Bay Area. Sign in to create job alert.", "score": 0.64880073, "raw_content": null}, {"url": "https://www.linkedin.com/jobs/view/senior-software-engineer-at-memorious-4271080044", "title": "Memorious hiring Senior Software Engineer in San ...", "content": "Get notified about new Senior Software Engineer jobs in San Francisco Bay Area. Sign in to create job alert. Apply. Similar jobs. Senior Backend Software", "score": 0.6437107, "raw_content": null}, {"url": "https://www.linkedin.com/jobs/view/software-engineer-forward-deployed-at-invisible-technologies-4270767806", "title": "Software Engineer - Forward Deployed", "content": "Get notified about new Software Engineer jobs in San Francisco Bay Area. Sign in to create job alert.", "score": 0.643173, "raw_content": null}, {"url": "https://www.linkedin.com/jobs/view/software-engineer-at-evolve-group-4268552903", "title": "Software Engineer - Evolve Group", "content": "Full-Stack/Front-end Software Engineer. San Francisco - In office. Total Comp: $215k - $290k + 0.4 - 0.6% Equity. About the Role.", "score": 0.38713467, "raw_content": null}, {"url": "https://www.linkedin.com/jobs/view/software-engineer-at-rise-technical-4268323907", "title": "Rise Technical hiring Software Engineer in San Francisco ...", "content": "Forward Deployed Engineer. $130,000 – $180,000 + Equity + Benefits + Relocation Assistance + PTO. San Francisco, CA – Hybrid (4 Days On-site).", "score": 0.34773698, "raw_content": null}], "response_time": 2.06}
# ================================== Ai Message ==================================
# Name: web_agent
#
# Here are 5 recent software engineer job postings in the Bay Area from LinkedIn:
#
# 1. Software Engineer, Developer Infra at Tecton
#    Location: San Francisco Bay Area
#    [View Job Posting](https://www.linkedin.com/jobs/view/software-engineer-developer-infra-at-tecton-4269808648)
#
# 2. Software Engineer I (Front End/Full Stack), Entry Level at Jobright.ai
#    Location: San Francisco Bay Area
#    [View Job Posting](https://www.linkedin.com/jobs/view/software-engineer-i-front-end-full-stack-entry-level-at-jobright-ai-4269775633)
#
# 3. Software Engineer - New Grad (Internship) at Jobright.ai
#    Location: San Francisco Bay Area
#    [View Job Posting](https://www.linkedin.com/jobs/view/software-engineer-new-grad-internship-at-jobright-ai-4268514143)
#
# 4. Software Engineer at Understanding Recruitment
#    Location: San Francisco Bay Area
#    [View Job Posting](https://www.linkedin.com/jobs/view/software-engineer-at-understanding-recruitment-4267476299)
#
# 5. Software Engineer, Product (Entry Level) at Jobright.ai
#    Location: San Francisco Bay Area
#    [View Job Posting](https://www.linkedin.com/jobs/view/software-engineer-product-entry-level-at-jobright-ai-4270230839)
#
# (Sources: LinkedIn job postings as of the past week)

# %% [markdown]
# Print the agent's final response as markdown.

# %%
# Print the agent's final response as markdown
Markdown(message.content)
# Out:
# Here are 5 recent software engineer job postings in the Bay Area from LinkedIn:
#
# 1. Software Engineer, Developer Infra at Tecton
#    Location: San Francisco Bay Area
#    [View Job Posting](https://www.linkedin.com/jobs/view/software-engineer-developer-infra-at-tecton-4269808648)
#
# 2. Software Engineer I (Front End/Full Stack), Entry Level at Jobright.ai
#    Location: San Francisco Bay Area
#    [View Job Posting](https://www.linkedin.com/jobs/view/software-engineer-i-front-end-full-stack-entry-level-at-jobright-ai-4269775633)
#
# 3. Software Engineer - New Grad (Internship) at Jobright.ai
#    Location: San Francisco Bay Area
#    [View Job Posting](https://www.linkedin.com/jobs/view/software-engineer-new-grad-internship-at-jobright-ai-4268514143)
#
# 4. Software Engineer at Understanding Recruitment
#    Location: San Francisco Bay Area
#    [View Job Posting](https://www.linkedin.com/jobs/view/software-engineer-at-understanding-recruitment-4267476299)
#
# 5. Software Engineer, Product (Entry Level) at Jobright.ai
#    Location: San Francisco Bay Area
#    [View Job Posting](https://www.linkedin.com/jobs/view/software-engineer-product-entry-level-at-jobright-ai-4270230839)
#
# (Sources: LinkedIn job postings as of the past week)

# %% [markdown]
# Notice how the agent cleverly combines Tavily’s tools—search, crawl, and extract—to complete the task end-to-end.
